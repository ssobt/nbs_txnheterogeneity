# %%
## Notebook env: brian_script_env (brian_script_env kernel)
## This notebook filters out GEMs that aren't confidentally assigned to only one guide by geomux in the 
## CRISPRi and CRISPRa cell culture screen

# %%
import scanpy as sc
import pandas as pd

# %%
CRISPRa_screen = sc.read_10x_h5('/home/ssobti/projects/heterogeneity_brian/data/072623_MD231_CRISPRa_repeat_screen/cellranger/combined_G12_CRISPRa_untethered/outs/count/filtered_feature_bc_matrix.h5')
# Out:
# /home/ssobti/miniconda3/envs/brian_script_env/lib/python3.10/site-packages/anndata/_core/anndata.py:1832: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
## loading barcode/guide assignments from geomux
import shelve

filenm = '/home/ssobti/projects/heterogeneity_brian/output_data/CRISPRa_repeat_screen/geomux_output_assignments_CRISPRa.out'
my_shelf = shelve.open(filenm)
for key in my_shelf:
    globals()[key]=my_shelf[key]
my_shelf.close()

# %%
assignments_CRISPRa
# Out:
#                                barcode     guide       lor         pvalue
# barcode
# AAACCCAAGCACCGAA-1  AAACCCAAGCACCGAA-1  CENPM-2a  7.345182  3.229035e-315  \
# AAACCCAAGTAACGTA-1  AAACCCAAGTAACGTA-1  CENPM-2a  7.748885  3.229035e-315
# AAACCCATCATCACTT-2  AAACCCATCATCACTT-2  AURKB-1a  7.345182  3.229035e-315
# AAACGAAAGATGAACT-2  AAACGAAAGATGAACT-2   RNF8-2a  1.309083   1.869624e-10
# AAACGAAAGTCGGGAT-1  AAACGAAAGTCGGGAT-1  HMGA1-1a  3.463437   4.141859e-37
# ...                                ...       ...       ...            ...
# TTTCGATGTCACTCAA-2  TTTCGATGTCACTCAA-2  NELFE-1a  2.630086   5.440826e-24
# TTTGGAGAGAAGCGGG-1  TTTGGAGAGAAGCGGG-1  JMJD6-1a  2.797227   6.819286e-32
# TTTGGTTAGTCGCCAC-1  TTTGGTTAGTCGCCAC-1  HMGA1-2a  7.287598  3.229035e-315
# TTTGGTTGTCCGGTGT-2  TTTGGTTGTCCGGTGT-2    NT-10a  7.617646  3.229035e-315
# TTTGGTTTCATTCCTA-1  TTTGGTTTCATTCCTA-1     NT-6a  7.345182  3.229035e-315
#
#                        adj_pvalue  max_umi  n_umi     m_umi     v_umi
# ...

# %%
assignments_CRISPRa.to_csv('/home/ssobti/projects/heterogeneity_brian/output_data/CRISPRa_repeat_screen/geomux_output_assignments_CRISPRa.csv')

# %%
CRISPRa_screen = CRISPRa_screen[assignments_CRISPRa['barcode'],:]
CRISPRa_screen.obs = assignments_CRISPRa
CRISPRa_screen.obs.index.name = None
# Out:
# /home/ssobti/miniconda3/envs/brian_script_env/lib/python3.10/site-packages/anndata/_core/anndata.py:1832: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
CRISPRa_screen.write_h5ad('/home/ssobti/projects/heterogeneity_brian/data/072623_MD231_CRISPRa_repeat_screen/geomux_filtered_data/CRISPRa_screen.h5ad')

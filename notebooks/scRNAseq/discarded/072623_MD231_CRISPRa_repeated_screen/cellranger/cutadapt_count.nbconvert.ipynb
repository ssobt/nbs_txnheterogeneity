# %%
# %%bash
#
# cutadapt -j20 --trimmed-only -m 20 -M 20 -a ^ANGCAGTGGTATCAACGCAGAGTACATGG...GTTTCAGAGCTAAGCACAA -a ^ANGCAGTGGTATCAACGCAGAGTACATGG...GTTTAAGAGCTAAGCTGGA -o /home/ssobti/projects/heterogeneity_brian/output_data/CRISPRa_repeat_screen/low_guides_trblsht/SL424_S3_L004_R2_001.trim_middle.fastq.gz /home/ssobti/projects/heterogeneity_brian/data/072623_MD231_CRISPRa_repeat_screen/BWHG37/SL424_S3_L004_R2_001.fastq.gz
# Out:
# This is cutadapt 4.4 with Python 3.10.12
# Command line parameters: -j20 --trimmed-only -m 20 -M 20 -a ^ANGCAGTGGTATCAACGCAGAGTACATGG...GTTTCAGAGCTAAGCACAA -a ^ANGCAGTGGTATCAACGCAGAGTACATGG...GTTTAAGAGCTAAGCTGGA -o /home/ssobti/projects/heterogeneity_brian/output_data/CRISPRa_repeat_screen/low_guides_trblsht/SL424_S3_L004_R2_001.trim_middle.fastq.gz /home/ssobti/projects/heterogeneity_brian/data/072623_MD231_CRISPRa_repeat_screen/BWHG37/SL424_S3_L004_R2_001.fastq.gz
# Processing single-end reads on 20 cores ...
# Finished in 240.377 s (1.036 µs/read; 57.94 M reads/minute).
#
# === Summary ===
#
# Total reads processed:             232,134,564
# Reads with adapters:               228,579,935 (98.5%)
#
# == Read fate breakdown ==
# Reads that were too short:             104,410 (0.0%)
# Reads that were too long:          231,938,499 (99.9%)
# Reads discarded as untrimmed:                0 (0.0%)
# Reads written (passing filters):        91,655 (0.0%)
#
# Total basepairs processed: 20,892,110,760 bp
# Total written (filtered):      1,833,100 bp (0.0%)
#
# === Adapter 1 ===
#
# Sequence: ANGCAGTGGTATCAACGCAGAGTACATGG...GTTTCAGAGCTAAGCACAA; Type: linked; Length: 29+19; 5' trimmed: 227307686 times; 3' trimmed: 4815001 times
#
# Minimum overlap: 29+3
# No. of allowed errors: 2
#
# No. of allowed errors:
# 1-9 bp: 0; 10-19 bp: 1
#
# Overview of removed sequences at 5' end
# length	count	expect	max.err	error counts
# 27	158995	0.0	2	0 0 158995
# 28	3025301	0.0	2	0 2904949 120352
# 29	222883139	0.0	2	217448641 4886219 548279
# 30	1232469	0.0	2	0 1193367 39102
# 31	7782	0.0	2	0 0 7782
#
#
#
# Overview of removed sequences at 3' end
# length	count	expect	max.err	error counts
# 3	2221188	3627102.6	0	2221188
# 4	796673	906775.6	0	796673
# 5	144304	226693.9	0	144304
# 6	30208	56673.5	0	30208
# 7	8692	14168.4	0	8692
# 8	590	3542.1	0	590
# 9	4723	885.5	0	549 4174
# 10	3865	221.4	1	91 3774
# 11	1492	55.3	1	2 1490
# 12	55	13.8	1	1 54
# 13	85	3.5	1	83 2
# 14	333	0.9	1	329 4
# 15	253	0.2	1	250 3
# 16	136	0.1	1	136
# 17	212	0.0	1	210 2
# 18	2	0.0	1	2
# 22	190	0.0	1	185 5
# 25	3	0.0	1	3
# 26	167	0.0	1	167
# 27	1	0.0	1	1
# 29	2	0.0	1	2
# 30	1532	0.0	1	1520 12
# 31	720	0.0	1	643 77
# 32	701	0.0	1	694 7
# 33	246	0.0	1	244 2
# 34	21	0.0	1	12 9
# 35	1801	0.0	1	1774 27
# 36	2039	0.0	1	1988 51
# 37	7678	0.0	1	7358 320
# 38	84223	0.0	1	81646 2577
# 39	1172390	0.0	1	1157207 15183
# 40	234300	0.0	1	231719 2581
# 41	45092	0.0	1	44509 583
# 42	35921	0.0	1	35391 530
# 43	10437	0.0	1	10220 217
# 44	1759	0.0	1	1747 12
# 45	500	0.0	1	480 20
# 46	298	0.0	1	297 1
# 47	324	0.0	1	323 1
# 48	209	0.0	1	209
# 49	105	0.0	1	104 1
# 50	240	0.0	1	237 3
# 51	306	0.0	1	301 5
# 52	480	0.0	1	472 8
# 53	199	0.0	1	197 2
# 54	55	0.0	1	54 1
# 55	91	0.0	1	90 1
# 56	24	0.0	1	24
# 57	34	0.0	1	34
# 58	76	0.0	1	76
# 59	20	0.0	1	20
# 60	6	0.0	1	6
#
#
# === Adapter 2 ===
#
# Sequence: ANGCAGTGGTATCAACGCAGAGTACATGG...GTTTAAGAGCTAAGCTGGA; Type: linked; Length: 29+19; 5' trimmed: 1272249 times; 3' trimmed: 1272249 times
#
# Minimum overlap: 29+3
# No. of allowed errors: 2
#
# No. of allowed errors:
# 1-9 bp: 0; 10-19 bp: 1
#
# Overview of removed sequences at 5' end
# length	count	expect	max.err	error counts
# 27	825	0.0	2	0 0 825
# 28	15885	0.0	2	0 15284 601
# 29	1248202	0.0	2	1226567 19873 1762
# 30	7297	0.0	2	0 7197 100
# 31	40	0.0	2	0 0 40
#
#
#
# Overview of removed sequences at 3' end
# length	count	expect	max.err	error counts
# 5	83576	226693.9	0	83576
# 6	24542	56673.5	0	24542
# 7	8560	14168.4	0	8560
# 8	835	3542.1	0	835
# 9	1017	885.5	0	63 954
# 10	2745	221.4	1	543 2202
# 11	662	55.3	1	14 648
# 12	215	13.8	1	138 77
# 13	2	3.5	1	1 1
# 14	311	0.9	1	310 1
# 15	139	0.2	1	139
# 20	77	0.0	1	77
# 21	6	0.0	1	6
# 23	54	0.0	1	54
# 25	6	0.0	1	6
# 26	59	0.0	1	59
# 27	1	0.0	1	1
# 32	112	0.0	1	112
# 33	34	0.0	1	34
# 34	10	0.0	1	9 1
# 35	241	0.0	1	221 20
# 36	1833	0.0	1	1722 111
# 37	6594	0.0	1	6176 418
# 38	60931	0.0	1	59432 1499
# 39	622057	0.0	1	614175 7882
# 40	350164	0.0	1	345894 4270
# 41	53219	0.0	1	52467 752
# 42	40792	0.0	1	40359 433
# 43	10734	0.0	1	10570 164
# 44	1432	0.0	1	1423 9
# 45	371	0.0	1	369 2
# 46	156	0.0	1	155 1
# 47	150	0.0	1	148 2
# 48	101	0.0	1	101
# 49	66	0.0	1	66
# 50	158	0.0	1	156 2
# 51	33	0.0	1	32 1
# 52	121	0.0	1	114 7
# 53	1	0.0	1	1
# 54	33	0.0	1	33
# 56	66	0.0	1	66
# 57	12	0.0	1	12
# 58	14	0.0	1	14
# 61	6	0.0	1	6
# 63	1	0.0	1	1

# %%
# %%bash
#
# cutadapt -j20 --trimmed-only -m 20 -M 20 -a ^ANGCAGTGGTATCAACGCAGAGTACATGG...GTTTCAGAGCTAAGCACAA -a ^ANGCAGTGGTATCAACGCAGAGTACATGG...GTTTAAGAGCTAAGCTGGA -o /home/ssobti/projects/heterogeneity_brian/output_data/CRISPRa_repeat_screen/low_guides_trblsht/SL425_S4_L004_R2_001.trim_middle.fastq.gz /home/ssobti/projects/heterogeneity_brian/data/072623_MD231_CRISPRa_repeat_screen/BWHG37/SL425_S4_L004_R2_001.fastq.gz
# Out:
# This is cutadapt 4.4 with Python 3.10.12
# Command line parameters: -j20 --trimmed-only -m 20 -M 20 -a ^ANGCAGTGGTATCAACGCAGAGTACATGG...GTTTCAGAGCTAAGCACAA -a ^ANGCAGTGGTATCAACGCAGAGTACATGG...GTTTAAGAGCTAAGCTGGA -o /home/ssobti/projects/heterogeneity_brian/output_data/CRISPRa_repeat_screen/low_guides_trblsht/SL425_S4_L004_R2_001.trim_middle.fastq.gz /home/ssobti/projects/heterogeneity_brian/data/072623_MD231_CRISPRa_repeat_screen/BWHG37/SL425_S4_L004_R2_001.fastq.gz
# Processing single-end reads on 20 cores ...
# Finished in 276.183 s (1.185 µs/read; 50.63 M reads/minute).
#
# === Summary ===
#
# Total reads processed:             233,071,550
# Reads with adapters:               228,058,125 (97.8%)
#
# == Read fate breakdown ==
# Reads that were too short:             143,777 (0.1%)
# Reads that were too long:          232,809,635 (99.9%)
# Reads discarded as untrimmed:                0 (0.0%)
# Reads written (passing filters):       118,138 (0.1%)
#
# Total basepairs processed: 20,976,439,500 bp
# Total written (filtered):      2,362,760 bp (0.0%)
#
# === Adapter 1 ===
#
# Sequence: ANGCAGTGGTATCAACGCAGAGTACATGG...GTTTCAGAGCTAAGCACAA; Type: linked; Length: 29+19; 5' trimmed: 226472557 times; 3' trimmed: 5331698 times
#
# Minimum overlap: 29+3
# No. of allowed errors: 2
#
# No. of allowed errors:
# 1-9 bp: 0; 10-19 bp: 1
#
# Overview of removed sequences at 5' end
# length	count	expect	max.err	error counts
# 27	158093	0.0	2	0 0 158093
# 28	3059039	0.0	2	0 2933004 126035
# 29	221974874	0.0	2	216877489 4620363 477022
# 30	1272375	0.0	2	0 1234680 37695
# 31	8176	0.0	2	0 0 8176
#
#
#
# Overview of removed sequences at 3' end
# length	count	expect	max.err	error counts
# 3	2367375	3641743.0	0	2367375
# 4	758357	910435.7	0	758357
# 5	150760	227608.9	0	150760
# 6	27556	56902.2	0	27556
# 7	8060	14225.6	0	8060
# 8	1849	3556.4	0	1849
# 9	4802	889.1	0	1594 3208
# 10	3629	222.3	1	67 3562
# 11	1112	55.6	1	6 1106
# 12	496	13.9	1	162 334
# 13	218	3.5	1	204 14
# 14	208	0.9	1	206 2
# 15	30	0.2	1	29 1
# 16	862	0.1	1	855 7
# 17	196	0.0	1	194 2
# 18	5	0.0	1	5
# 20	5	0.0	1	5
# 23	106	0.0	1	98 8
# 24	6	0.0	1	5 1
# 25	1	0.0	1	1
# 28	40	0.0	1	39 1
# 29	564	0.0	1	559 5
# 30	1374	0.0	1	1356 18
# 31	349	0.0	1	343 6
# 32	377	0.0	1	374 3
# 33	55	0.0	1	52 3
# 34	49	0.0	1	44 5
# 35	1779	0.0	1	1749 30
# 36	2705	0.0	1	2630 75
# 37	9728	0.0	1	9419 309
# 38	101925	0.0	1	98953 2972
# 39	1473672	0.0	1	1448931 24741
# 40	289857	0.0	1	286108 3749
# 41	52091	0.0	1	51280 811
# 42	49908	0.0	1	48815 1093
# 43	15599	0.0	1	15357 242
# 44	2267	0.0	1	2247 20
# 45	507	0.0	1	503 4
# 46	602	0.0	1	598 4
# 47	194	0.0	1	194
# 48	225	0.0	1	224 1
# 49	600	0.0	1	594 6
# 50	350	0.0	1	312 38
# 51	312	0.0	1	309 3
# 52	283	0.0	1	282 1
# 53	233	0.0	1	232 1
# 54	89	0.0	1	89
# 55	39	0.0	1	39
# 56	101	0.0	1	100 1
# 57	49	0.0	1	48 1
# 58	54	0.0	1	54
# 59	86	0.0	1	83 3
# 60	2	0.0	1	2
#
#
# === Adapter 2 ===
#
# Sequence: ANGCAGTGGTATCAACGCAGAGTACATGG...GTTTAAGAGCTAAGCTGGA; Type: linked; Length: 29+19; 5' trimmed: 1585568 times; 3' trimmed: 1585568 times
#
# Minimum overlap: 29+3
# No. of allowed errors: 2
#
# No. of allowed errors:
# 1-9 bp: 0; 10-19 bp: 1
#
# Overview of removed sequences at 5' end
# length	count	expect	max.err	error counts
# 27	777	0.0	2	0 0 777
# 28	19309	0.0	2	0 18896 413
# 29	1556900	0.0	2	1532742 22315 1843
# 30	8485	0.0	2	0 8330 155
# 31	97	0.0	2	0 0 97
#
#
#
# Overview of removed sequences at 3' end
# length	count	expect	max.err	error counts
# 5	81185	227608.9	0	81185
# 6	25909	56902.2	0	25909
# 7	9359	14225.6	0	9359
# 8	1197	3556.4	0	1197
# 9	1134	889.1	0	325 809
# 10	752	222.3	1	120 632
# 11	1618	55.6	1	222 1396
# 12	199	13.9	1	150 49
# 13	63	3.5	1	3 60
# 14	150	0.9	1	11 139
# 15	1	0.2	1	1
# 16	102	0.1	1	102
# 17	1	0.0	1	1
# 18	177	0.0	1	176 1
# 19	2	0.0	1	2
# 23	83	0.0	1	82 1
# 24	8	0.0	1	8
# 25	99	0.0	1	97 2
# 28	37	0.0	1	37
# 31	283	0.0	1	283
# 32	27	0.0	1	27
# 33	1	0.0	1	1
# 34	178	0.0	1	171 7
# 35	287	0.0	1	250 37
# 36	2580	0.0	1	2471 109
# 37	8176	0.0	1	7732 444
# 38	76200	0.0	1	74219 1981
# 39	764536	0.0	1	754720 9816
# 40	463929	0.0	1	458156 5773
# 41	73848	0.0	1	73015 833
# 42	55780	0.0	1	55143 637
# 43	12578	0.0	1	12410 168
# 44	3263	0.0	1	3227 36
# 45	383	0.0	1	305 78
# 46	230	0.0	1	230
# 47	282	0.0	1	279 3
# 48	219	0.0	1	218 1
# 49	224	0.0	1	224
# 50	204	0.0	1	204
# 51	54	0.0	1	54
# 52	93	0.0	1	93
# 53	11	0.0	1	11
# 54	21	0.0	1	21
# 55	2	0.0	1	2
# 57	101	0.0	1	101
# 58	2	0.0	1	2
